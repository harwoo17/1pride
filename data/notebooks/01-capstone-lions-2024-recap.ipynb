# %% [markdown]
# # Level 1 capstone — Lions 2024 season recap
#
# **Brief.** Tell the story of the Lions' 2024 regular season in one notebook. Weekly leaders, defensive standouts, and week-over-week changes. The reader should be able to run every cell top-to-bottom and get the same result.
#
# ## Evaluation criteria
#
# 1. The notebook **runs end-to-end** without manual intervention from a fresh Python env.
# 2. Every chart has a **title**, **axis labels**, and a **source caption** (`Source: nflverse`).
# 3. At least **one chart per category**: offense, defense, special teams.
# 4. Each section has **prose between cells** explaining what the query tells you — not just "here is a table."
# 5. The data source is **the local Postgres**, not a CSV. Reproducibility starts at the DB.
#
# ## Reference solution
#
# Reference solution will be released after you submit yours. Mark this notebook done by committing it to your fork of the `1pride` repo.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine

LIONS_BLUE = "#0076B6"
LIONS_SILVER = "#B0B7BC"

eng = create_engine("postgresql+psycopg://onepride:lions@localhost:5432/onepride")

# Sanity check
pd.read_sql("SELECT COUNT(*) AS rows FROM weekly_stats WHERE season = 2024", eng)

# %% [markdown]
# ## Section 1 — Offense
#
# *Goal: who carried the offense, and how did production move week to week?*
#
# Suggested charts:
# - Weekly passing yards (Goff) — line or bar across 18 weeks.
# - Rushing leaders (Montgomery / Gibbs) — horizontal bar of season totals.
# - Top-5 receivers by yards — horizontal bar.
#
# Write the SQL in one cell, a chart in the next, a short prose summary in markdown below it.

# %%
# TODO: weekly passing yards (Jared Goff, 2024 REG)
# Output shape: DataFrame with columns [week, passing_yards]

# %%
# TODO: matplotlib chart — Goff weekly passing yards
# Required: title, x-label, y-label, source caption

# %%
# TODO: rushing leaders (Lions, 2024 REG) — season totals per player

# %%
# TODO: rushing leaders chart

# %%
# TODO: top-5 receivers by yards

# %%
# TODO: top-5 receivers chart

# %% [markdown]
# ## Section 2 — Defense
#
# *Goal: where did the defense show up, and where did it struggle?*
#
# nflverse's `weekly_stats` is offense-heavy. For defense, you'll lean on the `schedules` table for points allowed, and you can pull per-game opponent stats by inverting the team filter.
#
# Suggested charts:
# - Points allowed per game — line across the season.
# - Average opponent passing yards by week.
# - (Stretch) Opponent QBR/EPA if you want to dig into nflverse PBP later.

# %%
# TODO: points allowed per Lions game, 2024 REG

# %%
# TODO: points-allowed chart

# %%
# TODO: opponent passing yards by week (sum across opponent players that week)

# %% [markdown]
# ## Section 3 — Special teams
#
# *Goal: a single chart that captures the special-teams story.*
#
# Suggested: Jake Bates' (or whoever is kicking) attempts/makes per game, or PR/KR return yardage per game. nflverse `weekly_stats` has limited ST data — you may need to enrich later, but for the capstone one clean ST chart is enough.

# %%
# TODO: special-teams chart of your choosing

# %% [markdown]
# ## Section 4 — Closing summary
#
# Write 3-5 sentences. What stood out? What surprised you? What would you want to investigate at Level 2?
#
# ---
#
# ## Submission checklist
#
# - [ ] Runs top-to-bottom from a fresh kernel
# - [ ] At least one chart per section (offense, defense, ST)
# - [ ] Every chart has title + axes + source caption
# - [ ] Prose between SQL and chart in each section
# - [ ] Committed to the `1pride` repo under `data/notebooks/`
